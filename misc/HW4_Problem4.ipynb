# %%
import tellurium as te

# %%
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline

# %% [markdown]
# #### Now, create a log-linear plot of your simulation results

# %%
# plot
plot = model.plot(sim, xscale="log")
